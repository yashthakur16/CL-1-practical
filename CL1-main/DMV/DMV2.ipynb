# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import contextily as ctx
import geopandas as gpd

# Replace 'your_api_key' with your actual API key
api_key = 'd85093f99a005c8686b89077d8d8a18f'
# Replace 'city_name' with the city you want to get weather data for
city_name = [
    "New York",
    "Los Angeles",
    "Chicago",
    "Houston",
    "Phoenix",
    "Philadelphia",
    "San Antonio",
    "San Diego",
    "Dallas",
    "San Jose",
    "Austin",
    "Jacksonville",
    "Fort Worth",
    "Columbus",
    "Charlotte",
    "San Francisco",
    "Indianapolis",
    "Seattle",
    "Denver",
    "Washington",
    "Boston",
    "El Paso",
    "Nashville",
    "Detroit",
    "Oklahoma City",
    "Portland",
    "Las Vegas",
    "Memphis",
    "Louisville",
    "Baltimore"
]

w_data=[]

for i in city_name:

  # Construct the URL
  base_url=f"http://api.openweathermap.org/data/2.5/weather?q={i}&appid={api_key}&units=metric%27"

  # Make a request to the API
  response = requests.get(base_url)

  # Check the response status code
  if response.status_code == 200:
      # Parse JSON data
      data = response.json()

      # Extract relevant data
      main = data['main']
      weather = data['weather'][0]
      wind = data['wind']

      city = i
      temp = main['temp']
      humidity = main['humidity']
      pressure = main['pressure']
      weather = weather['description']
      windspeed = wind['speed']
      log = data['coord']['lon']
      lat = data['coord']['lat']

      w_data.append({
          "City":city,
          "Temperature":temp,
          "Humidity":humidity,
          "Pressure":pressure,
          "Weather":weather,
          "Wind Speed":windspeed,
          "longitude":log,
          "latitude":lat
      })

  else:
      # Print the error message
      print(f"Error: {response.status_code}, {response.reason}")

df = pd.DataFrame(w_data)
df
# Out:
#              City  Temperature  Humidity  Pressure           Weather  \
# 0        New York       287.14        93      1009        light rain
# 1     Los Angeles       286.98        66      1017              mist
# 2         Chicago       283.55        80      1012     broken clouds
# 3         Houston       292.81        96      1015        light rain
# 4         Phoenix       290.04        24      1015     broken clouds
# 5    Philadelphia       287.87        96      1010        light rain
# 6     San Antonio       291.40        77      1016         clear sky
# 7       San Diego       285.60        72      1017              mist
# 8          Dallas       286.85        73      1017         clear sky
# 9        San Jose       284.92        76      1017         clear sky
# 10         Austin       289.95        83      1016         clear sky
# 11   Jacksonville       294.92        95      1015              mist
# 12     Fort Worth       286.08        70      1017         clear sky
# 13       Columbus       281.55        86      1013         clear sky
# 14      Charlotte       285.90        96      1015              mist
# 15  San Francisco       288.11        79      1016   overcast clouds
# 16   Indianapolis       280.59        86      1014         clear sky
# 17        Seattle       283.34        93      1001     moderate rain
# 18         Denver       275.67        61      1019         clear sky
# 19     Washington       277.03        86      1010     moderate rain
# 20         Boston       286.89        88      1006        light rain
# 21        El Paso       281.90        53      1018  scattered clouds
# 22      Nashville       288.11        93      1015         clear sky
# 23        Detroit       283.83        89      1008   overcast clouds
# 24  Oklahoma City       283.15        81      1018         clear sky
# 25       Portland       283.91        92      1002        light rain
# 26      Las Vegas       283.78        33      1016         clear sky
# 27        Memphis       286.40        90      1016         clear sky
# 28     Louisville       283.66        88      1015         clear sky
# 29      Baltimore       288.08        92      1011     moderate rain
#
#     Wind Speed  longitude  latitude
# 0         6.69   -74.0060   40.7143
# 1         0.00  -118.2437   34.0522
# 2         4.63   -87.6500   41.8500
# 3         1.68   -95.3633   29.7633
# 4         1.54  -112.0740   33.4484
# 5         4.02   -75.1638   39.9523
# 6         2.57   -98.4936   29.4241
# 7         3.09  -117.1573   32.7153
# 8         3.09   -96.7836   32.7668
# 9         3.60  -121.8950   37.3394
# 10        2.68   -97.7431   30.2672
# 11        3.09   -81.6556   30.3322
# 12        1.54   -97.3208   32.7254
# 13        4.12   -82.9988   39.9612
# 14        2.57   -80.8431   35.2271
# 15        4.12  -122.4194   37.7749
# 16        3.09   -86.1580   39.7684
# 17        4.92  -122.3321   47.6062
# 18        2.12  -104.9847   39.7392
# 19        1.61  -120.5015   47.5001
# 20        6.69   -71.0598   42.3584
# 21        3.09  -106.2005   31.8001
# 22        1.54   -86.7844   36.1659
# 23        0.45   -83.0458   42.3314
# 24        2.06   -97.5164   35.4676
# 25        5.14  -122.6762   45.5234
# 26        1.54  -115.1372   36.1750
# 27        2.57   -90.0490   35.1495
# 28        0.00   -85.7594   38.2542
# 29        3.60   -76.6122   39.2904

# %%
plt.figure(figsize=(15, 7))
sns.lineplot(x='City', y='Temperature', data=df)
# Adding title and labels
plt.title('Average Temperatures of 30 Cities')
plt.xlabel('Cities')
plt.ylabel('Average Temperature (°C)')

# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Adding a legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\RAJ\AppData\Local\Temp\ipykernel_18360\291933511.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df.describe()
# Out:
#        Temperature   Humidity     Pressure  Wind Speed   longitude   latitude
# count    30.000000  30.000000    30.000000   30.000000   30.000000  30.000000
# mean    285.667000  79.566667  1013.533333    2.915000  -97.620943  37.181463
# std       4.149935  17.694112     4.569263    1.674006   16.754894   5.057548
# min     275.670000  24.000000  1001.000000    0.000000 -122.676200  29.424100
# 25%     283.577500  73.750000  1011.250000    1.627500 -114.371400  32.937200
# 50%     285.990000  86.000000  1015.000000    2.885000  -97.052200  36.757200
# 75%     288.027500  92.000000  1016.750000    3.915000  -83.724200  39.958975
# max     294.920000  96.000000  1019.000000    6.690000  -71.059800  47.606200

# %%
plt.figure(figsize=(15, 7))
sns.barplot(x='City', y='Wind Speed', data=df)
# Adding title and labels
plt.title('Average Temperatures of 30 Cities')
plt.xlabel('Cities')
plt.ylabel('Average Temperature (°C)')

# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Adding a legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\RAJ\AppData\Local\Temp\ipykernel_18360\3563033918.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
gdf = gdf.set_crs(epsg=4326).to_crs(epsg=3857)

fig, ax = plt.subplots(figsize=(15, 10))
gdf.plot(ax=ax, color='blue', markersize=50, alpha=0.5)
ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)
plt.title('Geospatial Weather Data')
plt.show()

# %%
corr_matrix = df[['Temperature', 'Humidity', 'Wind Speed']].corr()

# Step 4: Visualize Relationships - Heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Weather Attributes')
plt.show()
